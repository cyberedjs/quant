# %%
import pandas as pd
import sqlalchemy
from binance.client import Client
from binance import BinanceSocketManager

# %%
api_key = "ncaGKCQNu9KS8kEwF3Jri37YjsOkKCfLGiKZcq87iThEU3QZIWdxOyeQLUvOCPpG"
api_secret = "tvSQ36Idx7W1QwiMx5ycduhziLQZaHUbhnHZGhqlSRaF6VrkP8QqsLY3LCidthdJ"

# %%
client = Client(api_key, api_secret)

# %%
client.get_account()
# Out:
# {'makerCommission': 10,
#  'takerCommission': 10,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'canTrade': True,
#  'canWithdraw': True,
#  'canDeposit': True,
#  'updateTime': 1634306210881,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'BTC', 'free': '0.00000064', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETH', 'free': '0.00000260', 'locked': '0.00000000'},
#   {'asset': 'NEO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOS', 'free': '0.00760000', 'locked': '0.00000000'},
#   {'asset': 'SNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GAS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCC', 'free': '0.00000000', 'locked': '0.00000000'},
# ...

# %%
#datastream via websocket - will not be covered in this one

# %%
pd.DataFrame(client.get_historical_klines('BTCUSDT', '1m', '30 m ago UTC'))
# Out:
#                0               1               2               3   \
# 0   1635079140000  60180.04000000  60287.79000000  60155.01000000
# 1   1635079200000  60285.93000000  60360.04000000  60262.03000000
# 2   1635079260000  60284.06000000  60321.85000000  60250.10000000
# 3   1635079320000  60300.01000000  60492.61000000  60274.27000000
# 4   1635079380000  60444.18000000  60487.10000000  60393.20000000
# 5   1635079440000  60470.61000000  60552.99000000  60400.70000000
# 6   1635079500000  60420.00000000  60496.58000000  60373.66000000
# 7   1635079560000  60474.74000000  60474.75000000  60411.68000000
# 8   1635079620000  60434.02000000  60503.67000000  60380.01000000
# 9   1635079680000  60492.43000000  60492.43000000  60448.09000000
# 10  1635079740000  60468.75000000  60523.42000000  60444.88000000
# 11  1635079800000  60504.11000000  60523.76000000  60452.56000000
# 12  1635079860000  60457.79000000  60466.62000000  60382.20000000
# ...

# %%
def getminutedata(symbol, interval, lookback):
    frame = pd.DataFrame(client.get_historical_klines(symbol, interval, lookback + ' min ago UTC'))
    frame = frame.iloc[:, :6]
    frame.columns = ['Time', 'Open', 'High', 'Low', 'Close', 'Volume']
    frame = frame.set_index('Time')
    frame.index = pd.to_datetime(frame.index, unit='ms')
    frame = frame.astype(float)
    return frame

# %%
getminutedata('BTCUSDT', '1m', '30m')
# Out:
#                          Open      High       Low     Close    Volume
# Time
# 2021-10-24 12:44:00  60470.61  60552.99  60400.70  60420.01  36.82132
# 2021-10-24 12:45:00  60420.00  60496.58  60373.66  60474.74  27.16340
# 2021-10-24 12:46:00  60474.74  60474.75  60411.68  60434.01  20.76651
# 2021-10-24 12:47:00  60434.02  60503.67  60380.01  60496.39  29.65596
# 2021-10-24 12:48:00  60492.43  60492.43  60448.09  60468.75  23.63291
# 2021-10-24 12:49:00  60468.75  60523.42  60444.88  60497.35  54.09463
# 2021-10-24 12:50:00  60504.11  60523.76  60452.56  60457.78  29.50278
# 2021-10-24 12:51:00  60457.79  60466.62  60382.20  60382.20  15.63439
# 2021-10-24 12:52:00  60382.20  60416.41  60310.34  60346.10  43.84274
# 2021-10-24 12:53:00  60345.99  60347.00  60256.03  60320.03  40.10648
# 2021-10-24 12:54:00  60320.04  60362.05  60300.00  60336.45  18.76950
# 2021-10-24 12:55:00  60336.44  60386.12  60327.08  60360.99  34.08877
# ...

# %%
test = getminutedata('BTCUSDT', '1m', '30m')

# %%
test.Open.plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
#buy if asset fell by more than 0.2% within the last 30 min
#sell if asset rises by more than 0.15% or fall further by 0.15%

# %%
def strategytest(symbol, qty, entried=False):
    df = getminutedata(symbol, '1m', '30m')
    cumulret = (df.Open.pct_change() +1).cumprod() - 1
    if not entried:
        if cumulret[-1] < -0.002:
            order = client.create_order(symbol=symbol, side='BUY', type='MARKET', quantity=qty)
            print(order)
            entried = True
        else:
            print('No Trade has been executed')
    if entried:
        while True:
            df = getminutedata(symbol, '1m', '30m')
            sincebuy = df.loc[df.index > pd.to_datetime(order['transactionTime'], unit='ms')]
            if len(sincebuy) > 0:
                sincebuyret = (sincebuy.Open.pct_change() +1).cumprod() - 1
                if sincebuyret[-1] > 0.0015 or sincebuyret[-1] < -0.0015:
                    order = client.create_order(symbol=symbol, side='SELL', type='MARKET', quantity=qty)
                    print(order)
                    break
