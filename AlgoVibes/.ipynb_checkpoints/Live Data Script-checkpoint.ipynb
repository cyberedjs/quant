# %%
import pandas as pd
import sqlalchemy
from binance.client import Client
from binance import BinanceSocketManager

# %%
api_key = "ncaGKCQNu9KS8kEwF3Jri37YjsOkKCfLGiKZcq87iThEU3QZIWdxOyeQLUvOCPpG"
api_secret = "tvSQ36Idx7W1QwiMx5ycduhziLQZaHUbhnHZGhqlSRaF6VrkP8QqsLY3LCidthdJ"

# %%
client = Client(api_key, api_secret)

# %%
bsm = BinanceSocketManager(client)

# %%
socket = bsm.trade_socket('BTCUSDT')

# %%
while True:
    await socket.__aenter__()
    msg = await socket.recv()
    frame = createframe(msg)
    frame.to_sql('BTCUSDT', engine, if_exists='append', index=False)
    print(frame)
# Out:
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:23.836  60480.33
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:24.226  60480.32
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:24.535  60480.33
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:24.696  60480.33
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:24.882  60480.33
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:24.882  60480.33
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:25.034  60483.95
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:25.176  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:25.284  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:25.479  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:25.578  60483.95
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:25.633  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:25.932  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:25.992  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:26.259  60483.95
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:26.689  60483.91
#     symbol                    Time    Price
# 0  BTCUSDT 2021-10-24 14:17:26.732  60483.9
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:26.732  60481.42
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:27.234  60483.89
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:27.637  60483.28
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:27.683  60483.28
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:28.193  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:28.215  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:28.467  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:28.467  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:29.034  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:29.658  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:30.195  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:30.279  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:30.292  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:30.656  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:30.981  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:31.311  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:31.407  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:31.850  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:31.988  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:32.116  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:32.130  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:32.426  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:33.069  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:33.998  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:34.002  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:34.357  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:34.836  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:34.836  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:34.883  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:35.334  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:35.334  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:35.460  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:35.774  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:35.774  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:35.774  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:36.001  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:36.127  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:36.163  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:36.163  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:36.163  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:36.163  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:36.163  60483.84
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:36.163  60480.85
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:36.163  60480.33
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:36.163  60480.26
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:36.163  60478.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:36.163  60478.77
#     symbol                    Time    Price
# 0  BTCUSDT 2021-10-24 14:17:36.163  60476.7
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:36.430  60483.85
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:36.694  60483.85
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:37.393  60480.32
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:37.431  60480.31
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:37.757  60480.31
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:37.954  60480.31
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:37.980  60480.31
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:38.043  60480.31
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:38.469  60480.36
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:39.011  60480.35
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:39.159  60480.36
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:39.159  60483.89
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:39.159  60483.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:39.159  60483.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:39.159  60484.97
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:39.159  60484.97
#     symbol                    Time    Price
# 0  BTCUSDT 2021-10-24 14:17:39.159  60487.0
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:39.159  60487.31
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:39.159  60487.53
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:39.159  60487.58
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:39.371  60480.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:39.387  60480.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:39.732  60480.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:39.985  60480.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:40.129  60480.93
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:40.135  60480.94
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:40.375  60480.98
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:40.375  60480.98
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:40.375  60481.02
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:40.443  60481.02
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:40.994  60481.01
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:41.248  60481.01
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:41.528  60481.02
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:41.528  60481.06
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:41.528  60483.93
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-8466111790b6> in async-def-wrapper()
#       5     frame.to_sql('BTCUSDT', engine, if_exists='append', index=False)
#       6     print(frame)
#
# <ipython-input-8-d473d1101cd0> in createframe(msg)
#       1 def createframe(msg):
#       2     df = pd.DataFrame([msg])
# ----> 3     df = df.loc[:, ['s', 'E', 'p']]
#       4     df.columns = ['symbol', 'Time', 'Price']
#       5     df.Price = df.Price.astype(float)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1053             return self._multi_take(tup)
#    1054
# -> 1055         return self._getitem_tuple_same_dim(tup)
#    1056
#    1057     def _get_label(self, label, axis: int):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     748                 continue
#     749
# --> 750             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     751             # We should never have retval.ndim < self.ndim, as that should
#     752             #  be handled by the _getitem_lowerdim call above.
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1097                     raise ValueError("Cannot index with multidimensional key")
#    1098
# -> 1099                 return self._getitem_iterable(key, axis=axis)
#    1100
#    1101             # nested tuple slicing
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1035
#    1036         # A collection of keys
# -> 1037         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1038         return self.obj._reindex_with_indexers(
#    1039             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['s', 'E', 'p'], dtype='object')] are in the [columns]"

# %%
def createframe(msg):
    df = pd.DataFrame([msg])
    df = df.loc[:, ['s', 'E', 'p']]
    df.columns = ['symbol', 'Time', 'Price']
    df.Price = df.Price.astype(float)
    df.Time = pd.to_datetime(df.Time, unit='ms')
    return df

# %%
createframe(msg)
# Out:
#     symbol                    Time     Price
# 0  BTCUSDT 2021-10-24 14:17:22.256  60479.74

# %%
engine = sqlalchemy.create_engine('sqlite:///BTCUSDTstream.db')
