# %%
import pandas as pd
import pandas_datareader as dr
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

sp500_url = 'https://en.wikipedia.org/wiki/List_of_S&P_500_companies'
data_table = pd.read_html(sp500_url)
tickers = data_table[0]['Symbol'].tolist()

tickers = tickers[0:60]

# %%
sp500_url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
data_table_security = pd.read_html(sp500_url)
security = data_table[0]['Security'].tolist()
security = security[0:60]

# %%
sp500_url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
data_table_security = pd.read_html(sp500_url)
sector = data_table[0]['GICS Sector'].tolist()
sector = security[0:60]

prices_list = []

# %%
print(len(tickers))
print(len(security))
print(len(sector))
# Out:
# 60
# 60
# 60

# %%
for ticker in tickers:
    try:
        prices = dr.DataReader(ticker, 'yahoo', '01/01/2017')['Adj Close']
        prices = pd.DataFrame(prices)
        prices.columns = [ticker]
        prices_list.append(prices)
    except:
        pass
    prices_df = pd.concat(prices_list, axis = 1)

prices_df.sort_index(inplace = True)
prices_df.head()
# Out:
#                    MMM        ABT       ABBV        ABMD         ACN  \
# Date
# 2017-01-03  155.622498  36.016212  50.757782  112.360001  108.282211
# 2017-01-04  155.858475  36.302132  51.473480  115.739998  108.542549
# 2017-01-05  155.325317  36.615711  51.863861  114.809998  106.915443
# 2017-01-06  155.779831  37.611813  51.880135  115.419998  108.133453
# 2017-01-09  154.940765  37.574924  52.221714  117.110001  106.924728
#
#                  ATVI        ADBE    AMD         AAP        AES  ...  \
# Date                                                             ...
# 2017-01-03  35.534649  103.480003  11.43  167.308853   9.918479  ...
# 2017-01-04  36.232922  104.139999  11.43  168.681808   9.833416  ...
# 2017-01-05  36.795425  105.910004  11.24  168.564178   9.705822  ...
# 2017-01-06  36.766335  108.300003  11.32  166.357513  10.054584  ...
# 2017-01-09  36.562668  108.570000  11.49  166.259460   9.807898  ...
#
#                   AJG        AIZ          T        ATO       ADSK        ADP  \
# Date
# 2017-01-03  47.586002  85.384369  32.314777  67.412842  76.180000  93.929581
# 2017-01-04  48.187191  86.264328  32.126976  67.792641  77.519997  94.074783
# 2017-01-05  48.296513  86.300613  32.036842  67.458046  76.930000  93.512093
# 2017-01-06  48.405811  87.071747  31.398540  67.069221  79.300003  93.575630
# 2017-01-09  47.731743  85.375290  31.003397  66.201118  79.589996  92.994804
#
#                    AZO         AVB        AVY        BKR
# Date
# 2017-01-03  791.460022  151.620651  64.486946  39.831497
# 2017-01-04  793.039978  152.247375  66.325760  39.660000
# 2017-01-05  792.000000  153.174500  65.672974  39.414993
# 2017-01-06  792.909973  154.522278  66.564796  39.176113
# 2017-01-09  790.340027  152.135773  66.711884  38.735107
#
# [5 rows x 60 columns]

# %%
df = prices_df.pct_change().iloc[1:].T
df.head()
# Out:
# Date  2017-01-04  2017-01-05  2017-01-06  2017-01-09  2017-01-10  2017-01-11  \
# MMM     0.001516   -0.003421    0.002926   -0.005386   -0.003892    0.007419
# ABT     0.007939    0.008638    0.027204   -0.000981    0.013500    0.001341
# ABBV    0.014100    0.007584    0.000314    0.006584   -0.002180   -0.036103
# ABMD    0.030082   -0.008035    0.005313    0.014642   -0.041585   -0.008642
# ACN     0.002404   -0.014990    0.011392   -0.011178    0.000522    0.009213
#
# Date  2017-01-12  2017-01-13  2017-01-17  2017-01-18  ...  2021-06-29  \
# MMM    -0.002530   -0.000282   -0.000733    0.006939  ...   -0.002392
# ABT    -0.008764    0.005157   -0.000733   -0.003423  ...    0.013051
# ABBV    0.002290    0.011586   -0.002097   -0.003233  ...   -0.006195
# ABMD    0.009886    0.029367   -0.014265   -0.006578  ...    0.002656
# ACN    -0.002928    0.010105   -0.007866   -0.000690  ...    0.008608
#
# Date  2021-06-30  2021-07-01  2021-07-02  2021-07-06  2021-07-07  2021-07-08  \
# MMM     0.013263    0.002316    0.004018   -0.015008    0.015085   -0.007956
# ABT    -0.010921    0.010610    0.007511    0.006608    0.008837   -0.005089
# ABBV    0.003028    0.014382    0.007964    0.004862    0.008814   -0.003426
# ABMD   -0.003703    0.002563    0.013135    0.030566    0.023936   -0.028368
# ACN    -0.005532    0.017674    0.016133    0.001837    0.013785   -0.001486
#
# Date  2021-07-09  2021-07-12  2021-07-13
# MMM     0.013769   -0.005075   -0.001900
# ABT     0.004025   -0.007767   -0.001347
# ABBV    0.001977    0.009007    0.002380
# ABMD   -0.000831   -0.008098   -0.009344
# ACN     0.011224   -0.003359    0.003402
#
# [5 rows x 1138 columns]

# %%
companies = list(df.index)
companies
movements = df.values
movements
# Out:
# array([[ 0.00151634, -0.00342078,  0.0029262 , ...,  0.01376908,
#         -0.00507465, -0.00190014],
#        [ 0.00793862,  0.00863805,  0.02720421, ...,  0.00402478,
#         -0.00776683, -0.00134665],
#        [ 0.01410027,  0.00758412,  0.00031377, ...,  0.00197682,
#          0.00900665,  0.0023804 ],
#        ...,
#        [ 0.0041335 ,  0.00608959,  0.00879897, ...,  0.01638513,
#          0.01421908, -0.01227843],
#        [ 0.02851451, -0.00984212,  0.01357975, ...,  0.01383271,
#          0.00038025, -0.01050226],
#        [-0.00430557, -0.00617767, -0.00606064, ...,  0.03459264,
#          0.01275851, -0.0282363 ]])

# %%
normalize = Normalizer()
array_norm = normalize.fit_transform(df)
df_norm = pd.DataFrame(array_norm, columns = df.columns)
final_df = df_norm.set_index(df.index)
final_df.head(10)
# Out:
# Date  2017-01-04  2017-01-05  2017-01-06  2017-01-09  2017-01-10  2017-01-11  \
# MMM     0.002787   -0.006288    0.005379   -0.009901   -0.007155    0.013638
# ABT     0.014625    0.015913    0.050116   -0.001807    0.024870    0.002470
# ABBV    0.023127    0.012439    0.000515    0.010799   -0.003576   -0.059214
# ABMD    0.033440   -0.008932    0.005906    0.016277   -0.046228   -0.009607
# ACN     0.004444   -0.027707    0.021056   -0.020661    0.000964    0.017028
# ATVI    0.026407    0.020863   -0.001062   -0.007444    0.024239    0.028712
# ADBE    0.009033    0.024071    0.031959    0.003531   -0.004044    0.009550
# AMD     0.000000   -0.013661    0.005849    0.012341   -0.003576   -0.017240
# AAP     0.010725   -0.000911   -0.017110   -0.000770    0.003007    0.026998
# AES    -0.011544   -0.017466    0.048370   -0.033026   -0.023350    0.052276
#
# Date  2017-01-12  2017-01-13  2017-01-17  2017-01-18  ...  2021-06-29  \
# MMM    -0.004650   -0.000518   -0.001347    0.012756  ...   -0.004397
# ABT    -0.016144    0.009501   -0.001351   -0.006306  ...    0.024043
# ABBV    0.003756    0.019003   -0.003440   -0.005303  ...   -0.010160
# ABMD    0.010990    0.032646   -0.015857   -0.007312  ...    0.002953
# ACN    -0.005412    0.018678   -0.014540   -0.001275  ...    0.015911
# ATVI   -0.002400   -0.006182    0.000000    0.004485  ...    0.002958
# ADBE   -0.005198   -0.000782   -0.006916    0.010360  ...    0.004690
# AMD    -0.032285   -0.013747   -0.059032    0.005021  ...    0.023027
# AAP     0.007838    0.002397   -0.013385    0.007404  ...    0.005049
# AES    -0.021730    0.016274    0.021822    0.002261  ...   -0.008118
#
# Date  2021-06-30  2021-07-01  2021-07-02  2021-07-06  2021-07-07  2021-07-08  \
# MMM     0.024382    0.004257    0.007387   -0.027589    0.027729   -0.014624
# ABT    -0.020118    0.019546    0.013837    0.012173    0.016279   -0.009375
# ABBV    0.004966    0.023589    0.013063    0.007975    0.014456   -0.005619
# ABMD   -0.004116    0.002849    0.014601    0.033978    0.026608   -0.031535
# ACN    -0.010226    0.032666    0.029819    0.003395    0.025479   -0.002746
# ATVI   -0.002389   -0.021684    0.005295    0.001853   -0.015517   -0.016274
# ADBE   -0.012250   -0.002201    0.020200    0.009146    0.021046    0.000421
# AMD     0.040484   -0.005424    0.012242   -0.001996   -0.034187   -0.007261
# AAP    -0.001019    0.024211    0.013199   -0.014553    0.004634   -0.012044
# AES    -0.015314    0.013425   -0.008691   -0.008233   -0.000518   -0.025897
#
# Date  2021-07-09  2021-07-12  2021-07-13
# MMM     0.025311   -0.009329   -0.003493
# ABT     0.007414   -0.014308   -0.002481
# ABBV    0.003242    0.014772    0.003904
# ABMD   -0.000923   -0.009002   -0.010387
# ACN     0.020746   -0.006208    0.006288
# ATVI    0.002916    0.007710    0.004918
# ADBE   -0.003389   -0.010074    0.011350
# AMD     0.010623   -0.000814   -0.004977
# AAP     0.037539   -0.009429   -0.018255
# AES     0.012674    0.011510   -0.053429
#
# [10 rows x 1138 columns]

# %%
col_mask = df.isnull().any(axis = 0)
row_mask = df.isnull().any(axis=1)
df.loc[row_mask, col_mask]
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
num_of_clusters = range(2,12)
error = []

for num_clusters in num_of_clusters:
    clusters = KMeans(num_clusters)
    clusters.fit(final_df)
    error.append(clusters.inertia_/100)
    
table = pd.DataFrame({"Cluster_Numbers":num_of_clusters, "Error_Term":error})
table
# Out:
#    Cluster_Numbers  Error_Term
# 0                2    0.313787
# 1                3    0.286009
# 2                4    0.275741
# 3                5    0.262935
# 4                6    0.258895
# 5                7    0.246709
# 6                8    0.238527
# 7                9    0.228684
# 8               10    0.225541
# 9               11    0.217082

# %%
plt.figure(figsize=(15,10))
plt.plot(table.Cluster_Numbers, table.Error_Term, marker = "D", color = 'red')
plt.xlabel('Number of Clusters')
plt.ylabel('SSE')
plt.show()

# %%
clusters = KMeans(7)
clusters.fit(final_df)
clusters.labels_

labels = clusters.predict(movements)
labels
# Out:
# array([2, 3, 1, 3, 1, 3, 3, 3, 4, 0, 0, 3, 2, 3, 0, 2, 5, 3, 3, 2, 6, 1,
#        3, 3, 5, 3, 2, 6, 0, 6, 0, 0, 5, 6, 1, 1, 2, 3, 2, 3, 3, 1, 1, 2,
#        0, 3, 3, 0, 2, 3, 1, 1, 1, 6, 3, 1, 4, 5, 2, 0], dtype=int32)

# %%
clustered_result = pd.DataFrame({'labels':labels, 'tickers':companies, 'full-name':security, 'sector':sector})
clustered_result.sort_values('labels')
# Out:
#     labels tickers                        full-name  \
# 59       0     BKR                     Baker Hughes
# 30       0     AXP                 American Express
# 14       0     ALK                 Alaska Air Group
# 28       0     AAL          American Airlines Group
# 44       0     APA                  APA Corporation
# 9        0     AES                         AES Corp
# 47       0    APTV                            Aptiv
# 10       0     AFL                            Aflac
# 31       0     AIG     American International Group
# 50       1     AJG        Arthur J. Gallagher & Co.
# 51       1     AIZ                         Assurant
# 34       1     AMP             Ameriprise Financial
# 4        1     ACN                        Accenture
# 52       1       T                             AT&T
# 42       1     AON                              Aon
# 2        1    ABBV                           AbbVie
# 41       1    ANTM                           Anthem
# 55       1     ADP        Automatic Data Processing
# 21       1     ALL                    Allstate Corp
# 35       1     ABC                AmerisourceBergen
# 58       2     AVY                   Avery Dennison
# 43       2     AOS                      A. O. Smith
# 38       2     APH                    Amphenol Corp
# 48       2     ADM                              ADM
# 36       2     AME                           Ametek
# 26       2    AMCR                            Amcor
# 0        2     MMM                               3M
# 12       2     APD         Air Products & Chemicals
# 19       2    ALLE                         Allegion
# 15       2     ALB            Albemarle Corporation
# 3        3    ABMD                          Abiomed
# 5        3    ATVI              Activision Blizzard
# 6        3    ADBE                            Adobe
# 49       3    ANET                  Arista Networks
# 7        3     AMD           Advanced Micro Devices
# 46       3    AMAT                Applied Materials
# 45       3    AAPL                            Apple
# 11       3       A             Agilent Technologies
# 25       3    AMZN                           Amazon
# 13       3    AKAM              Akamai Technologies
# 40       3    ANSS                            Ansys
# 39       3     ADI                   Analog Devices
# 37       3    AMGN                            Amgen
# 17       3    ALXN          Alexion Pharmaceuticals
# 18       3    ALGN                 Align Technology
# 22       3   GOOGL               Alphabet (Class A)
# 23       3    GOOG               Alphabet (Class C)
# 1        3     ABT              Abbott Laboratories
# 54       3    ADSK                         Autodesk
# 56       4     AZO                         AutoZone
# 8        4     AAP               Advance Auto Parts
# 16       5     ARE  Alexandria Real Estate Equities
# 32       5     AMT                   American Tower
# 57       5     AVB            AvalonBay Communities
# 24       5      MO                     Altria Group
# 27       6     AEE                      Ameren Corp
# 33       6     AWK             American Water Works
# 20       6     LNT                   Alliant Energy
# 53       6     ATO                     Atmos Energy
# 29       6     AEP          American Electric Power
#
#                              sector
# 59                     Baker Hughes
# 30                 American Express
# 14                 Alaska Air Group
# 28          American Airlines Group
# 44                  APA Corporation
# 9                          AES Corp
# 47                            Aptiv
# 10                            Aflac
# 31     American International Group
# 50        Arthur J. Gallagher & Co.
# 51                         Assurant
# 34             Ameriprise Financial
# 4                         Accenture
# 52                             AT&T
# 42                              Aon
# 2                            AbbVie
# 41                           Anthem
# 55        Automatic Data Processing
# 21                    Allstate Corp
# 35                AmerisourceBergen
# 58                   Avery Dennison
# 43                      A. O. Smith
# 38                    Amphenol Corp
# 48                              ADM
# 36                           Ametek
# 26                            Amcor
# 0                                3M
# 12         Air Products & Chemicals
# 19                         Allegion
# 15            Albemarle Corporation
# 3                           Abiomed
# 5               Activision Blizzard
# 6                             Adobe
# 49                  Arista Networks
# 7            Advanced Micro Devices
# 46                Applied Materials
# 45                            Apple
# 11             Agilent Technologies
# 25                           Amazon
# 13              Akamai Technologies
# 40                            Ansys
# 39                   Analog Devices
# 37                            Amgen
# 17          Alexion Pharmaceuticals
# 18                 Align Technology
# 22               Alphabet (Class A)
# 23               Alphabet (Class C)
# 1               Abbott Laboratories
# 54                         Autodesk
# 56                         AutoZone
# 8                Advance Auto Parts
# 16  Alexandria Real Estate Equities
# 32                   American Tower
# 57            AvalonBay Communities
# 24                     Altria Group
# 27                      Ameren Corp
# 33             American Water Works
# 20                   Alliant Energy
# 53                     Atmos Energy
# 29          American Electric Power

# %%
final_df['Cluster'] = clusters.labels_

# %%
plt.figure(figsize=(12,6))
sns.countplot(x = 'Cluster', data = final_df, palette = 'magma')
plt.title('Cluster_count')
plt.show()
plt.savefig('cluster_count.png', dpi = 300)
